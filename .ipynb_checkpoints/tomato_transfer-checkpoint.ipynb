# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.layers import Dense,Conv2D
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
from tensorflow.python.keras.layers import Dense, Flatten
from tensorflow.keras.applications import MobileNetV2
import numpy as np
from tensorflow.keras.callbacks import EarlyStopping
import cv2

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 224
CHANNELS=3

# %%
training_set= tf.keras.preprocessing.image_dataset_from_directory(
    "train",
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 10000 files belonging to 10 classes.

# %%
class_names = training_set.class_names
class_names
# Out:
# ['Tomato___Bacterial_spot',
#  'Tomato___Early_blight',
#  'Tomato___Late_blight',
#  'Tomato___Leaf_Mold',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Tomato___Target_Spot',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
#  'Tomato___Tomato_mosaic_virus',
#  'Tomato___healthy']

# %%
validation_set = tf.keras.preprocessing.image_dataset_from_directory(
    "val",
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 1000 files belonging to 10 classes.

# %%
plt.figure(figsize=(20, 10))
for image_batch, labels_batch in training_set.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, test_split=0.2, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split) == 1
    
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_split * ds_size)
    
    
    train_ds = ds.take(train_size)    
    test_ds = ds.skip(train_size)
    
    return train_ds, test_ds

# %%
train_ds, test_ds = get_dataset_partitions_tf(training_set)

# %%
len(training_set)
# Out:
# 313

# %%
len(train_ds)
# Out:
# 250

# %%
len(test_ds)
# Out:
# 63

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = validation_set.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
len(val_ds)
# Out:
# 32

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE, input_shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS)),
  layers.experimental.preprocessing.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 224
CHANNELS = 3
n_classes = 10

input_shape = (IMAGE_SIZE, IMAGE_SIZE, CHANNELS)

MobileNetV2_model = Sequential()

pretrained_model = MobileNetV2(include_top=False,
                               input_shape=input_shape,
                               pooling='avg',
                               weights='imagenet')

for layer in pretrained_model.layers:
    layer.trainable = False
    
MobileNetV2_model.add(pretrained_model)
MobileNetV2_model.add(resize_and_rescale)
MobileNetV2_model.add(data_augmentation)
MobileNetV2_model.add(Flatten())
MobileNetV2_model.add(Dense(512, activation='relu'))
MobileNetV2_model.add(Dense(n_classes, activation='softmax'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[202], line 13
#      10 base_model.trainable = False
#      12 # Build the complete model
# ---> 13 model = Sequential([
#      14     base_model,
#      15     layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
#      16     layers.experimental.preprocessing.Rescaling(1./255),
#      17     data_augmentation,
#      18     Flatten(),
#      19     Dense(512, activation='relu'),
#      20     Dense(n_classes, activation='softmax')
#      21 ])
#      23 # Compile the model
#      24 model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/trackable/base.py:204, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     202 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203 try:
# --> 204   result = method(self, *args, **kwargs)
#     205 finally:
#     206   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/ops/image_ops_impl.py:1467, in _resize_images_common(images, resizer_fn, size, preserve_aspect_ratio, name, skip_resize_if_same)
#    1465   images = array_ops.expand_dims(images, 0)
#    1466 elif images.get_shape().ndims != 4:
# -> 1467   raise ValueError('\'images\' must have either 3 or 4 dimensions.')
#    1469 _, height, width, _ = images.get_shape().as_list()
#    1471 try:
#
# ValueError: Exception encountered when calling layer "resizing_22" (type Resizing).
#
# 'images' must have either 3 or 4 dimensions.
#
# Call arguments received by layer "resizing_22" (type Resizing):
#   • inputs=tf.Tensor(shape=(None, 1280), dtype=float32)

# %%
MobileNetV2_model.summary()

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
MobileNetV2_model.compile(optimizer=opt,
                          loss="sparse_categorical_crossentropy",
                          metrics=['accuracy'])

# %%
epochs=10
history = MobileNetV2_model.fit(
    training_set,
    batch_size=32,
    validation_data=val_ds,
    epochs=epochs
)

# %%
scores = model.evaluate(test_ds)

# %%
scores

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(history.history['accuracy'], label='Training accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
plt.legend()
plt.show()

# %%
for images_batch, labels_batch in test_ds.take(1):

    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])

# %%
model.save("/Users/vidhan/Vidhan/data/Deep Learning/Projects/tomato_dataset")

# %%
model.save("tomatoessss.h5")

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")

# %%
model = tf.keras.models.load_model("E:\Deep Learning\Projects\Potato\Potato_disease\Model_original")

# %%
def predict(model, img):
    img = tf.image.resize(img, (256, 256))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = classes_name[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")

# %%
import gradio as gr

# %%
def predict_gradio(img):
    img = tf.image.resize(img, (256, 256))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = classes_name[np.argmax(predictions[0])]
    confidence = round(100 * np.max(predictions[0]), 2)
    return predicted_class

# %%
interface = gr.Interface(fn=predict_gradio,
             inputs=gr.Image(shape=(255, 255)),
             outputs=gr.Label(num_top_classes=3))

# %%
interface.launch()
